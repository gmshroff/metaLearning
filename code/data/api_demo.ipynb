# %%
from numin2 import Numin2API, NuminDataset, get_range_dataloader, get_month_dataloader
from torch.utils.data import DataLoader
import torch
import numpy as np 
import pandas as pd

# %%
client=Numin2API()

# %%
client.download_data(type='intraday',features='returns')

# %%
cf=pd.read_parquet('/tmp/consolidated_intraday_returns.parquet')

# %%
client.download_data(type='daily',features='returns')

# %%
cf=pd.read_parquet('/tmp/consolidated_daily_returns.parquet')

# %%
XR,YR=client.get_data_for_month(2025,12,target_type='raw',batch_size=4)

# %%
for x,y in zip(XR,YR):
    print(torch.tensor(x).shape,torch.tensor(y).shape)

# %%
new_dataloader=get_month_dataloader('/tmp/consolidated_daily_returns.parquet',month=11,year=2025,batch_size=4)

# %%
client.download_data(type='daily',features='ohlcv')

# %%
new_dataloader=get_range_dataloader('/tmp/consolidated_daily_ohlcv.parquet',start_month=1,start_year=2024,end_month=12,end_year=2024)

# %%
for x,y in new_dataloader:
    print(x.shape, y.shape)

# %%
positions = np.array([[1]+[1,1,0,-1,-1]*10,[0]+[1,1,0,-1,0]*10]).astype(np.float32)
targets = torch.tensor([[0,1,0,-1,-2]*10,[0,0,0,-1,-3]*10])

# %%
client.backtest_positions(positions,targets,txn_cost=0.1)

# %%
client.backtest_positions(positions,targets,txn_cost=0)

# %%
client.backtest_positions(positions,targets)

# %%
rf=client.fetch_intraday_raw_data(delta=280,features='returns')
